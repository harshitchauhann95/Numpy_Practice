# %%
"""Array name: electricity
shape (4,7)
rows Hostels(H1,H2,H3,H4)
COLUMN DAYS: (MON-SUN)
"""
# Out:
# 'Array name: electricity\nshape (4,7)\nrows Hostels(H1,H2,H3,H4)\nCOLUMN DAYS: (MON-SUN)\n'

# %%
import numpy as np

# %%
electricity=np.random.randint(120,650,size=(4,7))

electricity
# Out:
# array([[525, 222, 465, 318, 137, 605, 151],
#        [193, 433, 245, 290, 632, 579, 178],
#        [610, 634, 278, 200, 237, 620, 291],
#        [543, 398, 496, 257, 156, 548, 365]])

# %%
avg_r=np.mean(electricity,axis=1)
avg_r
# Out:
# array([346.14285714, 364.28571429, 410.        , 394.71428571])

# %%
avg_r.max()
# Out:
# np.float64(410.0)

# %%
avg_c=np.mean(electricity,axis=0)
avg_c
# Out:
# array([467.75, 421.75, 371.  , 266.25, 290.5 , 588.  , 246.25])

# %%
avg_c.max()
# Out:
# np.float64(588.0)

# %%
res=np.where(electricity>550,electricity*1.20,electricity)

# %%
res
# Out:
# array([[525. , 222. , 465. , 318. , 137. , 726. , 151. ],
#        [193. , 433. , 245. , 290. , 758.4, 694.8, 178. ],
#        [732. , 760.8, 278. , 200. , 237. , 744. , 291. ],
#        [543. , 398. , 496. , 257. , 156. , 548. , 365. ]])
